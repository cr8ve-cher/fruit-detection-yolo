# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 67.8 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xjEmAwOSlQxsRrEYqbnR")
project = rf.workspace("chers-workspace").project("fruits-h46zu")
version = project.version(7)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 83.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 126.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fruits-7 in yolov11:: 100%|██████████| 684/684 [00:00<00:00, 8513.85it/s]

# %%
# !yolo detect train data=/content/Fruits-7/data.yaml model=yolo11s.pt epochs=80 imgsz=640 optimizer=AdamW lr0=0.0008 patience=15 batch=16 hsv_h=0.015 hsv_s=0.7 hsv_v=0.4 scale=0.3 translate=0.1 mosaic=0.5
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.251 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r training_results.zip /content/runs/detect/train/
# Out:
#   adding: content/runs/detect/train/ (stored 0%)
#   adding: content/runs/detect/train/labels.jpg (deflated 31%)
#   adding: content/runs/detect/train/val_batch1_pred.jpg (deflated 19%)
#   adding: content/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/runs/detect/train/val_batch0_labels.jpg (deflated 17%)
#   adding: content/runs/detect/train/train_batch2.jpg (deflated 8%)
#   adding: content/runs/detect/train/train_batch1.jpg (deflated 7%)
#   adding: content/runs/detect/train/train_batch1261.jpg (deflated 10%)
#   adding: content/runs/detect/train/confusion_matrix.png (deflated 31%)
#   adding: content/runs/detect/train/train_batch0.jpg (deflated 8%)
#   adding: content/runs/detect/train/train_batch1262.jpg (deflated 13%)
#   adding: content/runs/detect/train/train_batch1260.jpg (deflated 12%)
#   adding: content/runs/detect/train/results.png (deflated 7%)
#   adding: content/runs/detect/train/BoxPR_curve.png (deflated 16%)
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/pexels-sami-aksu-48867324-9899253.jpg", save=True)
# Out:
# image 1/1 /content/pexels-sami-aksu-48867324-9899253.jpg: 448x640 5 Apples, 10 Bananas, 4 Grapess, 51.6ms
# Speed: 3.3ms preprocess, 51.6ms inference, 8.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict
